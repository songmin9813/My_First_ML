# %% [markdown]
# ## Class Imbalanced Problem을 해결하기 위한 방법
# - Resampling method
#   - Oversampling : 소수의 데이터를 부풀리는 방법
#   - Undersampling : 다수의 데이터를 줄이는 방법
#   - Hybrid resampling : Over+Undersampling의 혼합
#
#
# - Cost-sensitive learning
#   - Class의 오분류에 대한 cost의 가중치를 조절하여 학습하는 방법

# %% [markdown]
# ## Random Oversampling
# - 소수의 데이터를 random하게 sampling시켜 기존 데이터와 합치는 방법
# - Minority 데이터들을 랜덤하게 추출하여 샘플링시킴
# ![ex2.jpg](attachment:ex2.jpg)

# %% [markdown]
# ## SMOTE(Synthetic Minorty Over-sampling Technique)
# - 소수의 데이터 sample에 KNN을 적용한 후, 샘플과 이웃간 사이에 random하게 데이터 생성
# ![ex2.jpg](attachment:ex2.jpg)

# %% [markdown]
# - 단점 : 너무 많은 Minority를 만들어낼 경우, 다른 의미로의 overfitting이 일어날 수 있다.
#   - 이 역시 사용자의 역량에 따라 hyper parameter를 적용하도록 함

# %% [markdown]
# ## BLSMOTE(Borderline SMOTE)
# - Borderline에 있는 data는 class imbalanced problem에 큰 영향을 미친다고 판단하여 해당 dataset에만 SMOTE를 적용
# ![ex2.jpg](attachment:ex2.jpg)
# - 이미 주변 데이터가 많은 minority data는 이미 충분한 dataset을 가지고 있다 판단하여 추가적인 sampling을 진행하지 않음
# ![ex2.jpg](attachment:ex2.jpg)

# %% [markdown]
# ## DBSMOTE(DBSCAN SMOTE)
# - DBSCAN cluster 생성 후, cluster내에서 SMOTE 적용
# ![ex2.jpg](attachment:ex2.jpg)
