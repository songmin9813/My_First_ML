# %% [markdown]
# ## Machine Learning의 개념
# - 무엇(X)으로 무엇(Y)을 예측하고 싶다!
# - 인공지능의 한 분야. 컴퓨터가 학습할 수 있도록 하는 알고리즘과 기술을 개발하는 분야

# %% [markdown]
# $Y=f(X)$

# %% [markdown]
# - $Y$ : 출력변수, 종속변수, 반응변수
# - $f$ : 모형, 머신러닝 알고리즘
# - $X$ : 입력변수, 독립변수, feature

# %% [markdown]
# #### 결국 ML이란?
# - **주어진 데이터를 통해서 입력변수와 출력변수간의 관계를 만드는 함수 f를 만드는 것(지도 학습)**
# - **주어진 데이터 속에서 데이터의 특징을 찾아내는 함수 f를 만드는 것**

# %% [markdown]
# - ML로 할수 있는 것들
#   - X : 고객들의 개인 정보 및 금융 관련 정보, Y : 대출 연체 여부
#     - 대출 연체자 예측 탐지 모델, 대출 연체 관련 주요 feature 추출
#   - X : 게임 유저들의 게임 내 활동 정보, Y : 게임 이탈/어뷰징 여부
#     - 이상 탐지 모델
#   - X : 숫자 손 글씨 데이터, Y : 숫자 라벨(0~9)
#     - 숫자 이미지 분류 모델
#   - X : 상품 구매 고객 특성 정보
#     - 군집화를 통한 고객 특성에 따른 segmentation
#   - X : 고객들의 상품 구매 내역
#     - 매장 내 상품 진열 위치 리뉴얼을 통한 매출 증대
#   - X : 쇼핑몰 페이지 검색 및 클릭 로그 기록
#     - 맞춤 상품 추천 시스템
#   - X : SNS 데이터 및 뉴스 데이터
#     - 소셜 및 사회 이슈 파악

# %% [markdown]
# ## $f$란 무엇인가
#   - f를 구하기 위해서 입력 변수와 출력 변수가 필요함
#   - p개의 입력 변수 $X1,X2,X3,...,Xp$가 있고, 출력 변수 $Y$가 있을 때, $X=(X_1,X_2,...,X_p)$라 하면 입력 변수와 출력 변수의 관계를 나타내느 식은 다음과 같음
#
#
# > $Y=f(X)+\epsilon$

# %% [markdown]
# - $\epsilon$ : 예측치에 들어가는 보정값

# %% [markdown]
# ### 전 인구의 키를 예시로
# - 우리는 전체 인구의 키를 찾아낼 수 없기 때문에 특정 샘플을 뽑아내서 이를 통해 함수를 만든다.
#   - 여기서 말하는 샘플 데이터 = 학습 데이터
#   - 일부 샘플을 통해 얻어낸(추정한) 함수이기 때문에 햇을 이용하여 표기
#
# > $\hat{Y}=\hat{f}(X)$

# %% [markdown]
# ## 지도 학습(supervised learning) - Labeled data
# - $Y=f(X)$에 대하여 입력 변수 $(X)$와 출력 변수 $(Y)$의 관계에 대하여 모델링하는 것
#   - ($Y$에 대하여 예측, 또는 분류하는 문제)

# %% [markdown]
# - 회귀(regression) : 입력 변수 X에 대해서 **연속형 출력 변수 Y**를 예측
#   - 연속형 변수 : 연속적인 값(ex: 몸무게, MBI 등)
# - 분류(classification) : 입력 변수 X에 대해서 **이산형 출력 변수 Y(class)**를 예측
#   - 이산형 변수 : 클래스를 가지고 있는 것(ex: 흡연 여부, 오르거나 내리거나, 남녀 등)

# %% [markdown]
# ## 비지도 학습(unsupervised learning) - Unlabeled data
# - 출력 변수 (Y)가 존재하지 않고, 입력 변수 (X)간의 관계에 대해 모델링하는 것
# - 군집 분석 - 유사한 데이터끼리 그룹화
# - PCA - 독립변수들의 차원을 축소화

# %% [markdown]
# ![ex1.jpg](attachment:ex1.jpg)

# %% [markdown]
# - 현실에서는 Y값이 존재하지 않은 경우도 굉장히 많다. 둘 다 중요함

# %% [markdown]
# ## 강화학습(reinforcement learning)
# - 수많은 시뮬레이션을 통해 현재의 선택이 먼 미래에 보상이 최대가 되도록 학습
# - Agent가 action을 취하고 환경에서 보상을 받고, 이 보상이 최대가 최도록 최적의 action을 취하는 방법을 배움
