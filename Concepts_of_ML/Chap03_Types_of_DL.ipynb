# %% [markdown]
# ## 딥러닝의 주요모델
# - Neural Network
#   - 입력, 은닉, 출력층으로 구성된 모형. 각 층을 연결하는 노드의 가중치를 업데이트하면서 학습
#     - overfitting과 학습시간이 매우 오래걸림

# %% [markdown]
# - Deep Learning
#   - 다층의 layer를 통해 복잡한 데이터의 학습이 가능토록 함
#   - 알고리즘 및 GPU의 발전이 deep learning의 부흥을 이끌었다는 생각
#   - graphical representation learning
#   - 이미지 처리에 사용되는 CNN(Convolutional Neural Network)

# %% [markdown]
# - 이미지 분류에서의 기존 모델
#   - 각각의 픽셀 값을 늘어뜨려서 독립변수로 사용
#   - 독립변수들은 각각 독립이라는 기본적인 가정에서 어긋남

# %% [markdown]
# - CNN
#   - 이미지의 지역별 feature를 뽑아서 여러 개의 input를 만든다.

# %% [markdown]
# - CNN 뿐만이 아니라 다양한 형태로 발전해왔다.(RNNm AutoEncoder 등)

# %% [markdown]
# ![ex1.jpg](attachment:ex1.jpg)

# %% [markdown]
# - Object detection, Image Resolution, Style transfer, colorization 등 다양한 분야로 발전

# %% [markdown]
# - Deep learning은 네트워크 구조의 발전에도 이바지함
#   - 네트워크 초기화 기법(Xavier, he initialization 등)
#   - 다양한 activation function(ReLu, ELU, SuLU, Leaky ReLU 등)
#   - Generalization, overfitting에 관한 문제
#   - Semi-supervised learning, Unsupervised learning

# %% [markdown]
# ### GAN(Generative Adersarial Nerwork) - Deep Learning
# - Data를 만들어내는 Generator와 만들어진 data를 평가하는 Discriminator가 서로 대립(Adversarial)적으로 학습해가며 성능을 점차 개선해 나가자는 개념

# %% [markdown]
# - Dicsriminator를 학습시킬 때에는 $D(x)$(real data)가 1이 되고, $D(G(z))$(생성기에 넣은 가짜 데이터)가 0이 되도록 학습시킴
#   - 진짜 데이터를 진짜로 판별하고, 가짜 데이터를 가짜로 판별할 수 있도록
# - Generator를 학습시킬 때에는 $D(G(z))$가 1이 되도록 학습시킴
#   - 가짜 데이터를 discriminator가 구분 못하도록 학습, discriminator를 헷갈리게 하도록 학습

# %% [markdown]
# - State Of The Art-Sota
#   - 가장 최신식의 : 해당 기능에서 이 모델이 가장 좋은 모델임을 의미. Sota는 계속 바뀐다.
#   - BigGAN, CycleGAN, Photo style transfer, High-res in-painting(중간 공백을 채워넣는 미션) 등 여러 분야에서 GAN이 사용

# %% [markdown]
# ### 강화학습(Reinforcement Learning)
# - Q-learning
#   - 현재 상태에서 먼 미래까지 가장 큰 보상을 얻을 수 있는 행동을 학습하게 하는 것
# - Q-learning + Deep Learning : DQN(Deep Reinforcement Learning)
#
#
# > $\hat{Q}(s,a)=r+\gamma maxQ(s',a')$
#
#
#   - $\hat{Q}(s,a)$ : 예상되는 최종 보상
#   - $r$ : 즉시 얻을 수 있는 보상
#   - $\gamma max$ : 지연된 보상의 가치 감소 비율
#   - $maxQ(s',a')$ : 할인 누적 보상

# %% [markdown]
# - Deep Reinforcement Learning
#   - 더 효율적으로 빠르게 학습할 수 있는 강화학습 모델
#   - Action이 continuous한 경우
#   - Reward가 매우 sparse(부족)한 경우
#   - Multi agent 강화학습 모델
#
#
# - 기본적으로 State, Action, Reward 3개가 존재해야 함

# %% [markdown]
# - Atari game, Unity game 환경 내에서 강화학습을 진행하는 경우가 많음

# %% [markdown]
# #### ML, DL(GAN, Reinforcement  Learning 등) 모든 것을 다 알아야 필요가 있다. 전부는 아니더라도 개념적으로는 알아가야 함
